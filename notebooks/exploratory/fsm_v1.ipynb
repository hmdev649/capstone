# %% [markdown]
# This notebook shows the simplest E2E workflow for the FSM that demonstrates the workflow. The results can then be evaluated using the subjective, offline evaluation scale.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# import needed external libraries
import os
import sys
import pandas as pd
import string, re

import nltk
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction import text
import sklearn

# Include the `src` module in the module path for imports
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# import custom functions
from src.functions import prep

# %%
#read in needed data
df_comments = pd.read_csv('../../src/data/csv_exports/q_comments.csv')
df_metadata = pd.read_csv('../../src/data/csv_exports/metadata.csv')

# %%
# extract article titles
titles = df_metadata['article_title']

# %%
# extract comments text
q_comments = df_comments['comment_text']

# %%
# define preprocessing steps
def pre_vec(q_list):
    pre_vec = []
    
    for q in q_list:
        q = prep.tokenize(q)
        q = prep.lowercase(q)
#         q = prep.rem_stop(q)
        q = prep.stem(q)
        q = ' '.join(q)
        
        pre_vec.append(q)
        
    return pre_vec

# %%
# preprocess article titles and comments text
titles_pre_vec = pre_vec(titles)
qc_pre_vec = pre_vec(q_comments)

# %%
# initialize tfidf vectorizer
tfidf = sklearn.feature_extraction.text.TfidfVectorizer()

# %%
# fit vectorizer to comments text, transform comments text
qc_tfidf = tfidf.fit_transform(qc_pre_vec)

# transform article titles
titles_tfidf = tfidf.transform(titles_pre_vec)

# %%
# calculate cosine similarity matrix
sim_counts = pd.DataFrame(cosine_similarity(qc_tfidf, titles_tfidf))

# %%
# return article and comment metadata for all pairs with 
# cosine similarity scores > 0.8

count = 0

for i in sim_counts:
    if sim_counts[i].max() > 0.8:
        print(sim_counts[i].max())
        print(df_comments.loc[sim_counts[i].idxmax()])
        print(df_metadata.loc[i], '\n\n')
        
        count+=1
        
print(count)
# Out:
# 0.8048369462785332
# Unnamed: 0                              24038
# article_num                              4293
# comment_id                              26575
# commenter_name                       duckjibe
# comment_published    2017-10-04T11:45:28.000Z
# comment_text                         Hublot ?
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 4983, dtype: object
# article_id                                                         719
# article_cat                                              Not Specified
# article_title        The Hublot Atelier: The Hublot for when your o...
# article_author                                            Felix Scholz
# article_published                            2012-10-03 09:00:00-04:00
# article_modified                             2017-02-20 21:01:21-05:00
# comm_count                                                         -42
# word_count                                                         275
# Name: 719, dtype: object
#
#
# 0.8690051270790933
# Unnamed: 0                              27970
# article_num                              4302
# comment_id                              30750
# commenter_name                            CCP
# comment_published    2017-11-14T06:50:19.000Z
# comment_text                    Who is Pras?!
# comment_likes                               7
# comment_flag                                0
# parent_id                                   0
# Name: 5789, dtype: object
# article_id                                1558
# article_cat                    Talking Watches
# article_title                        With Pras
# article_author                 Benjamin Clymer
# article_published    2014-12-17 10:36:00-05:00
# article_modified     2019-12-19 09:52:22-05:00
# comm_count                                 -42
# word_count                                 463
# Name: 1558, dtype: object
#
#
# 0.8577075723172534
# Unnamed: 0                              34070
# article_num                              4524
# comment_id                              37235
# commenter_name                         vic123
# comment_published    2018-01-16T00:23:50.000Z
# comment_text               Tag Heuer Carrera?
# comment_likes                               1
# comment_flag                                0
# parent_id                                   0
# Name: 7013, dtype: object
# article_id                                                  1594
# article_cat                                  A Week On The Wrist
# article_title        The TAG Heuer Carrera 1887 41mm Chronograph
# article_author                                 Stephen Pulvirent
# article_published                      2014-11-21 19:11:00-05:00
# article_modified                       2019-12-13 17:49:14-05:00
# comm_count                                                   -42
# word_count                                                  1924
# Name: 1594, dtype: object
#
#
# 0.8202185582101024
# Unnamed: 0                              93143
# article_num                              5654
# comment_id                              98914
# commenter_name                     EdipisReks
# comment_published    2019-03-31T01:34:23.000Z
# comment_text                   Is a DateJust?
# comment_likes                               0
# comment_flag                                0
# parent_id                               98894
# Name: 17852, dtype: object
# article_id                                1798
# article_cat                A Week On The Wrist
# article_title               The Rolex Datejust
# article_author               Stephen Pulvirent
# article_published    2014-06-26 13:49:00-04:00
# article_modified     2019-12-04 20:52:51-05:00
# comm_count                                 -42
# word_count                                3457
# Name: 1798, dtype: object
#
#
# 0.8127645001801314
# Unnamed: 0                                      46041
# article_num                                      4794
# comment_id                                      49741
# commenter_name                                 SimonK
# comment_published            2018-03-30T21:23:04.000Z
# comment_text         How come you missed Eric Singer?
# comment_likes                                       0
# comment_flag                                        0
# parent_id                                           0
# Name: 9354, dtype: object
# article_id                                1879
# article_cat                    Talking Watches
# article_title                 With Eric Singer
# article_author                 Benjamin Clymer
# article_published    2014-05-01 10:00:00-04:00
# article_modified     2020-03-17 12:51:07-04:00
# comm_count                                 -42
# word_count                                 985
# Name: 1879, dtype: object
#
#
# 0.8605278426408924
# Unnamed: 0                              51148
# article_num                              4877
# comment_id                              55069
# commenter_name                         Edward
# comment_published    2018-05-09T17:41:19.000Z
# comment_text             Paul Newman Daytona?
# comment_likes                               1
# comment_flag                                0
# parent_id                               55031
# Name: 10304, dtype: object
# article_id                                                  2139
# article_cat                                     Reference Points
# article_title        Understanding The Rolex Paul Newman Daytona
# article_author                                   Benjamin Clymer
# article_published                      2014-04-03 11:35:00-04:00
# article_modified                       2019-12-04 21:30:19-05:00
# comm_count                                                   -42
# word_count                                                  3226
# Name: 2139, dtype: object
#
#
# 0.929328595628317
# Unnamed: 0                             119132
# article_num                              6056
# comment_id                             126554
# commenter_name                      3WatchGuy
# comment_published    2019-11-12T10:05:47.000Z
# comment_text                   Or John Mayer?
# comment_likes                               0
# comment_flag                                0
# parent_id                              126481
# Name: 22461, dtype: object
# article_id                                2168
# article_cat                    Talking Watches
# article_title                  With John Mayer
# article_author                 Benjamin Clymer
# article_published    2013-09-25 12:23:00-04:00
# article_modified     2019-12-04 20:56:07-05:00
# comm_count                                 -42
# word_count                                 772
# Name: 2168, dtype: object
#
#
# 0.8566535268459947
# Unnamed: 0                              34070
# article_num                              4524
# comment_id                              37235
# commenter_name                         vic123
# comment_published    2018-01-16T00:23:50.000Z
# comment_text               Tag Heuer Carrera?
# comment_likes                               1
# comment_flag                                0
# parent_id                                   0
# Name: 7013, dtype: object
# article_id                                                  2195
# article_cat                                        Not Specified
# article_title        The TAG Heuer Carrera With Caliber Heuer 01
# article_author                                    Blake Buettner
# article_published                      2015-03-18 14:51:24-04:00
# article_modified                       2017-02-20 21:06:57-05:00
# comm_count                                                   -42
# word_count                                                   271
# Name: 2195, dtype: object
#
#
# 0.8202185582101024
# Unnamed: 0                              93143
# article_num                              5654
# comment_id                              98914
# commenter_name                     EdipisReks
# comment_published    2019-03-31T01:34:23.000Z
# comment_text                   Is a DateJust?
# comment_likes                               0
# comment_flag                                0
# parent_id                               98894
# Name: 17852, dtype: object
# article_id                                        2457
# article_cat                                   Hands-On
# article_title        The Rolex Datejust Pearlmaster 39
# article_author                            Jack Forster
# article_published            2015-08-14 12:49:18-04:00
# article_modified             2017-02-20 21:06:52-05:00
# comm_count                                         -42
# word_count                                        1198
# Name: 2457, dtype: object
#
#
# 0.8043194685869075
# Unnamed: 0                                                       48586
# article_num                                                       4829
# comment_id                                                       52364
# commenter_name                                              seikofiver
# comment_published                             2018-04-19T10:55:35.000Z
# comment_text         You mean like this?\nhttps://www.hodinkee.com/...
# comment_likes                                                        1
# comment_flag                                                         0
# parent_id                                                        52261
# Name: 9826, dtype: object
# article_id                                                        2470
# article_cat                                      The Value Proposition
# article_title        A Seventy-Five Dollar Watch That Looks Like A ...
# article_author                                            Jack Forster
# article_published                            2015-08-20 12:33:33-04:00
# article_modified                             2017-08-01 10:35:30-04:00
# comm_count                                                         -42
# word_count                                                         981
# Name: 2470, dtype: object
#
#
# 0.8574026884031813
# Unnamed: 0                                                      103811
# article_num                                                       5854
# comment_id                                                      110227
# commenter_name                                                homieliu
# comment_published                             2019-07-01T15:41:49.000Z
# comment_text         The Tudor Heritage Black Bay Black Side of the...
# comment_likes                                                        3
# comment_flag                                                         0
# parent_id                                                            0
# Name: 19725, dtype: object
# article_id                                         2591
# article_cat                                 Introducing
# article_title        The Tudor Heritage Black Bay Black
# article_author                             Cara Barrett
# article_published             2015-10-14 14:00:37-04:00
# article_modified              2017-02-20 20:58:48-05:00
# comm_count                                          -42
# word_count                                          309
# Name: 2591, dtype: object
#
#
# 0.8031522731318446
# Unnamed: 0                                                      103811
# article_num                                                       5854
# comment_id                                                      110227
# commenter_name                                                homieliu
# comment_published                             2019-07-01T15:41:49.000Z
# comment_text         The Tudor Heritage Black Bay Black Side of the...
# comment_likes                                                        3
# comment_flag                                                         0
# parent_id                                                            0
# Name: 19725, dtype: object
# article_id                                                        2592
# article_cat                                        A Week On The Wrist
# article_title        The Tudor Heritage Black Bay Black Reference 7...
# article_author                                              John Mayer
# article_published                            2015-10-15 09:30:33-04:00
# article_modified                             2017-04-25 09:46:48-04:00
# comm_count                                                         -42
# word_count                                                        1478
# Name: 2592, dtype: object
#
#
# 0.8836945441086238
# Unnamed: 0                              24023
# article_num                              4293
# comment_id                              26560
# commenter_name                         GB_man
# comment_published    2017-10-04T05:29:53.000Z
# comment_text               Is that a Cartier?
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 4979, dtype: object
# article_id                                2815
# article_cat                           Hands-On
# article_title              The Cartier Hypnose
# article_author                    Cara Barrett
# article_published    2016-02-09 09:37:00-05:00
# article_modified     2017-02-20 21:04:01-05:00
# comm_count                                 -42
# word_count                                 719
# Name: 2815, dtype: object
#
#
# 0.8358132743848442
# Unnamed: 0                                                       21572
# article_num                                                       4234
# comment_id                                                       23990
# commenter_name                                                imageWIS
# comment_published                             2017-09-08T16:50:54.000Z
# comment_text         May I direct you to this article? https://www....
# comment_likes                                                        0
# comment_flag                                                         0
# parent_id                                                        23773
# Name: 4301, dtype: object
# article_id                                                        2985
# article_cat                                             Watch Spotting
# article_title        What Jeremy Irons And Ben Affleck Wore In Batm...
# article_author                                            Jack Forster
# article_published                            2016-04-20 11:31:36-04:00
# article_modified                             2017-02-20 21:04:48-05:00
# comm_count                                                         -42
# word_count                                                         628
# Name: 2985, dtype: object
#
#
# 0.8593927967687367
# Unnamed: 0                               3394
# article_num                              3725
# comment_id                               3620
# commenter_name                   jjhughes1969
# comment_published    2017-02-08T21:26:59.000Z
# comment_text                 Ochs und Junior?
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 578, dtype: object
# article_id                                             3117
# article_cat                                     Introducing
# article_title        The Ochs Und Junior Perpetual Calendar
# article_author                                 Jack Forster
# article_published                 2016-06-28 03:07:36-04:00
# article_modified                  2017-05-17 09:21:57-04:00
# comm_count                                              -42
# word_count                                             1152
# Name: 3117, dtype: object
#
#
# 0.8154419866995437
# Unnamed: 0                              68946
# article_num                              5213
# comment_id                              73670
# commenter_name                      RafaNunez
# comment_published    2018-10-10T01:02:00.000Z
# comment_text              Roger Smith anyone?
# comment_likes                               9
# comment_flag                                0
# parent_id                                   0
# Name: 13570, dtype: object
# article_id                                3278
# article_cat           The Road Through Britain
# article_title        Episode 1: Roger W. Smith
# article_author                  Arthur Touchot
# article_published    2016-09-13 10:32:00-04:00
# article_modified     2019-12-04 15:33:53-05:00
# comm_count                                 -42
# word_count                                1411
# Name: 3278, dtype: object
#
#
# 0.8270280506044134
# Unnamed: 0                              28093
# article_num                              4370
# comment_id                              30883
# commenter_name                        Mustard
# comment_published    2017-11-14T22:54:51.000Z
# comment_text                         SalonQP?
# comment_likes                               0
# comment_flag                                0
# parent_id                               30834
# Name: 5825, dtype: object
# article_id                                     3426
# article_cat                            Photo Report
# article_title        Watch Spotting At SalonQP 2016
# article_author                       Arthur Touchot
# article_published         2016-11-07 16:12:16-05:00
# article_modified          2017-02-20 21:04:53-05:00
# comm_count                                      -42
# word_count                                       93
# Name: 3426, dtype: object
#
#
# 0.8593927967687367
# Unnamed: 0                               3394
# article_num                              3725
# comment_id                               3620
# commenter_name                   jjhughes1969
# comment_published    2017-02-08T21:26:59.000Z
# comment_text                 Ochs und Junior?
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 578, dtype: object
# article_id                                             3456
# article_cat                                        Hands-On
# article_title        The Ochs Und Junior Perpetual Calendar
# article_author                            Stephen Pulvirent
# article_published                 2016-11-17 11:01:19-05:00
# article_modified                  2017-05-17 09:22:57-04:00
# comm_count                                              -42
# word_count                                             1183
# Name: 3456, dtype: object
#
#
# 0.9127007682292475
# Unnamed: 0                                                        2437
# article_num                                                       3687
# comment_id                                                        2593
# commenter_name                                                   Lange
# comment_published                             2017-01-28T20:41:44.000Z
# comment_text         How about Ulysse Nardin Classico Manufacture '...
# comment_likes                                                        0
# comment_flag                                                         0
# parent_id                                                            0
# Name: 399, dtype: object
# article_id                                                        3620
# article_cat                                                Introducing
# article_title        The Ulysse Nardin Classico Manufacture 'Grand ...
# article_author                                          Arthur Touchot
# article_published                            2017-01-16 01:00:17-05:00
# article_modified                             2017-02-20 20:55:53-05:00
# comm_count                                                           4
# word_count                                                         359
# Name: 3620, dtype: object
#
#
# 0.9127007682292475
# Unnamed: 0                                                        2437
# article_num                                                       3687
# comment_id                                                        2593
# commenter_name                                                   Lange
# comment_published                             2017-01-28T20:41:44.000Z
# comment_text         How about Ulysse Nardin Classico Manufacture '...
# comment_likes                                                        0
# comment_flag                                                         0
# parent_id                                                            0
# Name: 399, dtype: object
# article_id                                                        3668
# article_cat                                                   Hands-On
# article_title        The Ulysse Nardin Classico Manufacture 'Grand ...
# article_author                                          Arthur Touchot
# article_published                            2017-01-19 15:10:41-05:00
# article_modified                             2017-02-20 21:02:53-05:00
# comm_count                                                          23
# word_count                                                         503
# Name: 3668, dtype: object
#
#
# 0.8081080416098162
# Unnamed: 0                                 2209
# article_num                                3685
# comment_id                                 2354
# commenter_name                   pennfootball71
# comment_published      2017-01-26T18:29:44.000Z
# comment_text         This or the Heuer Autavia?
# comment_likes                                 0
# comment_flag                                  0
# parent_id                                     0
# Name: 346, dtype: object
# article_id                                 3849
# article_cat                         Introducing
# article_title        The 2017 TAG Heuer Autavia
# article_author                   Arthur Touchot
# article_published     2017-03-22 05:01:15-04:00
# article_modified      2017-04-25 06:35:34-04:00
# comm_count                                   59
# word_count                                  497
# Name: 3849, dtype: object
#
#
# 0.8106985281325645
# Unnamed: 0                                     100075
# article_num                                      5785
# comment_id                                     106300
# commenter_name                                    HAR
# comment_published            2019-05-30T22:19:39.000Z
# comment_text         Movement made by Greubel Forsey?
# comment_likes                                       0
# comment_flag                                        0
# parent_id                                           0
# Name: 19074, dtype: object
# article_id                                3920
# article_cat                A Week On The Wrist
# article_title           The Greubel Forsey GMT
# article_author                    Jack Forster
# article_published    2017-04-14 14:22:55-04:00
# article_modified     2017-04-25 08:34:48-04:00
# comm_count                                  39
# word_count                                1606
# Name: 3920, dtype: object
#
#
# 0.9395590754895343
# Unnamed: 0                              51148
# article_num                              4877
# comment_id                              55069
# commenter_name                         Edward
# comment_published    2018-05-09T17:41:19.000Z
# comment_text             Paul Newman Daytona?
# comment_likes                               1
# comment_flag                                0
# parent_id                               55031
# Name: 10304, dtype: object
# article_id                                                   4053
# article_cat                                                 Found
# article_title        Paul Newman's Paul Newman Daytona, Seriously
# article_author                                    Benjamin Clymer
# article_published                       2017-06-01 10:06:15-04:00
# article_modified                        2017-06-01 10:14:10-04:00
# comm_count                                                    171
# word_count                                                    625
# Name: 4053, dtype: object
#
#
# 0.8081080416098162
# Unnamed: 0                                 2209
# article_num                                3685
# comment_id                                 2354
# commenter_name                   pennfootball71
# comment_published      2017-01-26T18:29:44.000Z
# comment_text         This or the Heuer Autavia?
# comment_likes                                 0
# comment_flag                                  0
# parent_id                                     0
# Name: 346, dtype: object
# article_id                                 4274
# article_cat                 A Week On The Wrist
# article_title        The TAG Heuer Autavia 2017
# article_author                         Jon Bues
# article_published     2017-10-05 13:58:00-04:00
# article_modified      2019-12-04 19:08:58-05:00
# comm_count                                   87
# word_count                                 3403
# Name: 4274, dtype: object
#
#
# 0.9718884782513535
# Unnamed: 0                              51148
# article_num                              4877
# comment_id                              55069
# commenter_name                         Edward
# comment_published    2018-05-09T17:41:19.000Z
# comment_text             Paul Newman Daytona?
# comment_likes                               1
# comment_flag                                0
# parent_id                               55031
# Name: 10304, dtype: object
# article_id                                        4317
# article_cat                                   Hands-On
# article_title        Paul Newman's Paul Newman Daytona
# article_author                       Stephen Pulvirent
# article_published            2017-10-16 09:32:59-04:00
# article_modified             2017-10-25 11:32:56-04:00
# comm_count                                          70
# word_count                                        1024
# Name: 4317, dtype: object
#
#
# 0.9250209781780092
# Unnamed: 0                              99897
# article_num                              5779
# comment_id                             106094
# commenter_name                         Franzy
# comment_published    2019-05-29T22:22:38.000Z
# comment_text                 Where's Wei Koh?
# comment_likes                               3
# comment_flag                                0
# parent_id                                   0
# Name: 19046, dtype: object
# article_id                                4421
# article_cat                    Talking Watches
# article_title                     With Wei Koh
# article_author                 Benjamin Clymer
# article_published    2017-12-13 11:27:00-05:00
# article_modified     2019-12-04 14:36:15-05:00
# comm_count                                 171
# word_count                                 703
# Name: 4421, dtype: object
#
#
# 0.8136355914179101
# Unnamed: 0                                                       98026
# article_num                                                       5749
# comment_id                                                      104143
# commenter_name                                              Polerouter
# comment_published                             2019-05-13T07:59:18.000Z
# comment_text         This or a Moser Swiss Icons watch? I can't dec...
# comment_likes                                                        0
# comment_flag                                                         0
# parent_id                                                            0
# Name: 18723, dtype: object
# article_id                                     4507
# article_cat                             Introducing
# article_title        The H. Moser Swiss Icons Watch
# article_author                         Jack Forster
# article_published         2018-01-10 18:01:33-05:00
# article_modified          2018-01-11 07:56:15-05:00
# comm_count                                      209
# word_count                                      554
# Name: 4507, dtype: object
#
#
# 0.8995427547473795
# Unnamed: 0                              68946
# article_num                              5213
# comment_id                              73670
# commenter_name                      RafaNunez
# comment_published    2018-10-10T01:02:00.000Z
# comment_text              Roger Smith anyone?
# comment_likes                               9
# comment_flag                                0
# parent_id                                   0
# Name: 13570, dtype: object
# article_id                                4606
# article_cat                    Talking Watches
# article_title                 With Roger Smith
# article_author                    Jack Forster
# article_published    2018-02-15 10:29:00-05:00
# article_modified     2019-12-04 14:39:07-05:00
# comm_count                                 186
# word_count                                 703
# Name: 4606, dtype: object
#
#
# 0.8539180933062651
# Unnamed: 0                                                 39865
# article_num                                                 4652
# comment_id                                                 43320
# commenter_name                                          rolexero
# comment_published                       2018-03-03T04:26:21.000Z
# comment_text         How about the new Breitling Navitimer 8? :)
# comment_likes                                                  0
# comment_flag                                                   0
# parent_id                                                  43229
# Name: 8227, dtype: object
# article_id                                    4611
# article_cat                            Introducing
# article_title        The Breitling Navitimer 8 B01
# article_author                            Jon Bues
# article_published        2018-01-28 13:39:30-05:00
# article_modified         2018-01-28 16:53:05-05:00
# comm_count                                     152
# word_count                                     418
# Name: 4611, dtype: object
#
#
# 0.9395116567774942
# Unnamed: 0                              34070
# article_num                              4524
# comment_id                              37235
# commenter_name                         vic123
# comment_published    2018-01-16T00:23:50.000Z
# comment_text               Tag Heuer Carrera?
# comment_likes                               1
# comment_flag                                0
# parent_id                                   0
# Name: 7013, dtype: object
# article_id                                     4653
# article_cat                             Introducing
# article_title        The TAG Heuer Carrera Heuer 02
# article_author                             Jon Bues
# article_published         2018-02-19 09:05:03-05:00
# article_modified          2018-02-19 09:05:06-05:00
# comm_count                                       70
# word_count                                      571
# Name: 4653, dtype: object
#
#
# 0.8539180933062651
# Unnamed: 0                                                 39865
# article_num                                                 4652
# comment_id                                                 43320
# commenter_name                                          rolexero
# comment_published                       2018-03-03T04:26:21.000Z
# comment_text         How about the new Breitling Navitimer 8? :)
# comment_likes                                                  0
# comment_flag                                                   0
# parent_id                                                  43229
# Name: 8227, dtype: object
# article_id                                    4673
# article_cat                               Hands-On
# article_title        The Breitling Navitimer 8 B01
# article_author                        Jason Heaton
# article_published        2018-02-28 11:49:54-05:00
# article_modified         2018-02-28 11:49:56-05:00
# comm_count                                     108
# word_count                                    1310
# Name: 4673, dtype: object
#
#
# 0.8971736729695793
# Unnamed: 0                                   54302
# article_num                                   4924
# comment_id                                   58335
# commenter_name                            Danny470
# comment_published         2018-06-07T19:11:28.000Z
# comment_text         Who (or what) is Arnold&Son ?
# comment_likes                                    0
# comment_flag                                     0
# parent_id                                        0
# Name: 10872, dtype: object
# article_id                                    4692
# article_cat                            Introducing
# article_title        The Arnold & Son Globetrotter
# article_author                        Jack Forster
# article_published        2018-03-16 14:31:56-04:00
# article_modified         2018-03-20 12:12:40-04:00
# comm_count                                      18
# word_count                                     700
# Name: 4692, dtype: object
#
#
# 0.8203544190413147
# Unnamed: 0                                                      125839
# article_num                                                       6319
# comment_id                                                      133817
# commenter_name                                                    pofu
# comment_published                             2020-01-14T02:38:23.000Z
# comment_text         Is the Bulgari Octo Finissimo Tourbillon not t...
# comment_likes                                                        0
# comment_flag                                                         0
# parent_id                                                            0
# Name: 23649, dtype: object
# article_id                                                        4765
# article_cat                                                 First Take
# article_title        The Bulgari Octo Finissimo Tourbillon Automati...
# article_author                                            Cara Barrett
# article_published                            2018-03-22 17:50:00-04:00
# article_modified                             2019-12-04 21:57:42-05:00
# comm_count                                                          33
# word_count                                                          86
# Name: 4765, dtype: object
#
#
# 0.8051010089104194
# Unnamed: 0                                      12369
# article_num                                      3899
# comment_id                                      13788
# commenter_name                         Sonomiracolino
# comment_published            2017-05-24T11:42:22.000Z
# comment_text         Patek Philippe Calatrava ref 96?
# comment_likes                                       0
# comment_flag                                        0
# parent_id                                       13779
# Name: 2293, dtype: object
# article_id                                                        4775
# article_cat                                                   Hands-On
# article_title        The Patek Philippe Calatrava Pilot Travel Time...
# article_author                                            Cara Barrett
# article_published                            2018-03-24 07:54:14-04:00
# article_modified                             2018-03-24 07:54:22-04:00
# comm_count                                                          34
# word_count                                                         457
# Name: 4775, dtype: object
#
#
# 0.8971736729695793
# Unnamed: 0                                   54302
# article_num                                   4924
# comment_id                                   58335
# commenter_name                            Danny470
# comment_published         2018-06-07T19:11:28.000Z
# comment_text         Who (or what) is Arnold&Son ?
# comment_likes                                    0
# comment_flag                                     0
# parent_id                                        0
# Name: 10872, dtype: object
# article_id                                    4924
# article_cat                               Hands-On
# article_title        The Arnold & Son Globetrotter
# article_author                   Stephen Pulvirent
# article_published        2018-06-07 09:18:37-04:00
# article_modified         2018-06-07 09:18:41-04:00
# comm_count                                      18
# word_count                                     929
# Name: 4924, dtype: object
#
#
# 0.8030084110091068
# Unnamed: 0                              76422
# article_num                              5383
# comment_id                              81468
# commenter_name                        Caminet
# comment_published    2018-12-27T03:22:36.000Z
# comment_text                Don McLean? Nope.
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 14928, dtype: object
# article_id                                4992
# article_cat                    Talking Watches
# article_title                  With Don McLean
# article_author                    Cara Barrett
# article_published    2018-07-12 13:29:00-04:00
# article_modified     2019-12-04 14:34:23-05:00
# comm_count                                 163
# word_count                                1017
# Name: 4992, dtype: object
#
#
# 0.811944264314782
# Unnamed: 0                              95584
# article_num                              5690
# comment_id                             101489
# commenter_name                    furrywrists
# comment_published    2019-04-17T17:36:28.000Z
# comment_text                $495 for a Timex?
# comment_likes                               7
# comment_flag                                0
# parent_id                                   0
# Name: 18280, dtype: object
# article_id                                5066
# article_cat                        Introducing
# article_title        The Timex x Greats Bayman
# article_author               Stephen Pulvirent
# article_published    2018-08-02 12:03:08-04:00
# article_modified     2018-08-02 12:03:59-04:00
# comm_count                                  65
# word_count                                 552
# Name: 5066, dtype: object
#
#
# 0.8740536015136096
# Unnamed: 0                              86810
# article_num                              5568
# comment_id                              92283
# commenter_name                           jay1
# comment_published    2019-03-08T18:57:12.000Z
# comment_text              Who is Todd Snyder?
# comment_likes                               1
# comment_flag                                0
# parent_id                                   0
# Name: 16726, dtype: object
# article_id                                5083
# article_cat                     HODINKEE Radio
# article_title           Episode 6: Todd Snyder
# article_author               Stephen Pulvirent
# article_published    2018-08-13 09:08:08-04:00
# article_modified     2018-08-17 13:35:03-04:00
# comm_count                                  28
# word_count                                 538
# Name: 5083, dtype: object
#
#
# 0.8199433027361873
# Unnamed: 0                               3394
# article_num                              3725
# comment_id                               3620
# commenter_name                   jjhughes1969
# comment_published    2017-02-08T21:26:59.000Z
# comment_text                 Ochs und Junior?
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 578, dtype: object
# article_id                                               5278
# article_cat                                       Introducing
# article_title        The Ochs und Junior Annual Calendar 36mm
# article_author                              Stephen Pulvirent
# article_published                   2018-11-06 09:03:00-05:00
# article_modified                    2018-11-06 09:03:04-05:00
# comm_count                                                 60
# word_count                                                590
# Name: 5278, dtype: object
#
#
# 0.8355157722414688
# Unnamed: 0                             119132
# article_num                              6056
# comment_id                             126554
# commenter_name                      3WatchGuy
# comment_published    2019-11-12T10:05:47.000Z
# comment_text                   Or John Mayer?
# comment_likes                               0
# comment_flag                                0
# parent_id                              126481
# Name: 22461, dtype: object
# article_id                                5501
# article_cat                    Talking Watches
# article_title          With John Mayer, Part 2
# article_author                 Benjamin Clymer
# article_published    2019-03-27 10:03:00-04:00
# article_modified     2019-12-04 14:15:13-05:00
# comm_count                                 433
# word_count                                1954
# Name: 5498, dtype: object
#
#
# 0.9722785481182172
# Unnamed: 0                             121500
# article_num                              6226
# comment_id                             129134
# commenter_name                          tick1
# comment_published    2019-12-06T05:23:23.000Z
# comment_text                         SWATCH.?
# comment_likes                               3
# comment_flag                                0
# parent_id                                   0
# Name: 22861, dtype: object
# article_id                                5514
# article_cat                        Introducing
# article_title              The Swatch Flymagic
# article_author               Stephen Pulvirent
# article_published    2019-02-14 09:59:26-05:00
# article_modified     2019-02-14 09:59:50-05:00
# comm_count                                 102
# word_count                                 611
# Name: 5511, dtype: object
#
#
# 0.8207220581609977
# Unnamed: 0                               3394
# article_num                              3725
# comment_id                               3620
# commenter_name                   jjhughes1969
# comment_published    2017-02-08T21:26:59.000Z
# comment_text                 Ochs und Junior?
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 578, dtype: object
# article_id                                                5541
# article_cat                                        Introducing
# article_title        The Ochs Und Junior Two Time Zones + Date
# article_author                               Stephen Pulvirent
# article_published                    2019-02-28 09:01:22-05:00
# article_modified                     2019-02-28 09:01:24-05:00
# comm_count                                                  41
# word_count                                                 732
# Name: 5538, dtype: object
#
#
# 0.9284564517256652
# Unnamed: 0                              95584
# article_num                              5690
# comment_id                             101489
# commenter_name                    furrywrists
# comment_published    2019-04-17T17:36:28.000Z
# comment_text                $495 for a Timex?
# comment_likes                               7
# comment_flag                                0
# parent_id                                   0
# Name: 18280, dtype: object
# article_id                                5755
# article_cat                        Introducing
# article_title                      The Q Timex
# article_author                 Cole Pennington
# article_published    2019-05-16 11:20:24-04:00
# article_modified     2019-05-17 15:24:18-04:00
# comm_count                                 239
# word_count                                 733
# Name: 5750, dtype: object
#
#
# 0.9017969415264132
# Unnamed: 0                                                      111189
# article_num                                                       5985
# comment_id                                                      118082
# commenter_name                                                Coopster
# comment_published                             2019-09-04T14:06:10.000Z
# comment_text         Why The Bao Dai Is One Of The Coolest Rolex Wa...
# comment_likes                                                        0
# comment_flag                                                         0
# parent_id                                                            0
# Name: 21010, dtype: object
# article_id                                                        5985
# article_cat                                              Sunday Rewind
# article_title        Why The Bao Dai Is One Of The Coolest Rolex Wa...
# article_author                                       Stephen Pulvirent
# article_published                            2019-09-01 10:56:00-04:00
# article_modified                             2019-09-01 13:36:22-04:00
# comm_count                                                          17
# word_count                                                         229
# Name: 5972, dtype: object
#
#
# 0.8033313083809582
# Unnamed: 0                                                      117897
# article_num                                                       6121
# comment_id                                                      125233
# commenter_name                                                  Shanej
# comment_published                             2019-10-30T14:08:07.000Z
# comment_text         'Three Of The Best Lange 1s Ever Made Are Up F...
# comment_likes                                                        0
# comment_flag                                                         0
# parent_id                                                            0
# Name: 22255, dtype: object
# article_id                                                        6121
# article_cat                                                      Found
# article_title        Three Of The Best Lange 1s Ever Made Are Up Fo...
# article_author                                         Benjamin Clymer
# article_published                            2019-10-29 13:14:00-04:00
# article_modified                             2019-10-29 14:34:16-04:00
# comm_count                                                          43
# word_count                                                        1055
# Name: 6100, dtype: object
#
#
# 0.8725765710744338
# Unnamed: 0                               3394
# article_num                              3725
# comment_id                               3620
# commenter_name                   jjhughes1969
# comment_published    2017-02-08T21:26:59.000Z
# comment_text                 Ochs und Junior?
# comment_likes                               0
# comment_flag                                0
# parent_id                                   0
# Name: 578, dtype: object
# article_id                                    6165
# article_cat                               In-Depth
# article_title        The Ochs Und Junior Day/Night
# article_author                        Jack Forster
# article_published        2019-11-11 14:49:00-05:00
# article_modified         2019-11-11 16:28:54-05:00
# comm_count                                      42
# word_count                                    1659
# Name: 6140, dtype: object
#
#
# 0.8474979194335414
# Unnamed: 0                                               39406
# article_num                                               4668
# comment_id                                               42835
# commenter_name                                        MTechnic
# comment_published                     2018-02-28T15:58:22.000Z
# comment_text         A LIMITED EDITION Bremont? You don’t say!
# comment_likes                                                3
# comment_flag                                                 0
# parent_id                                                    0
# Name: 8142, dtype: object
# article_id                                               6187
# article_cat                                          Hands-On
# article_title        The Bremont H-4 Hercules Limited Edition
# article_author                                   James Stacey
# article_published                   2019-11-20 08:57:00-05:00
# article_modified                    2019-11-20 23:42:31-05:00
# comm_count                                                 46
# word_count                                                894
# Name: 6161, dtype: object
#
#
# 0.8195087383149416
# Unnamed: 0                                     10768
# article_num                                     3963
# comment_id                                     12098
# commenter_name                       WestVillageOkie
# comment_published           2017-04-29T12:39:05.000Z
# comment_text         $75000 for a 1962 Submariner???
# comment_likes                                      3
# comment_flag                                       0
# parent_id                                          0
# Name: 1994, dtype: object
# article_id                                6212
# article_cat                      Sunday Rewind
# article_title         A Submariner From SEALAB
# article_author                        HODINKEE
# article_published    2019-12-01 11:28:25-05:00
# article_modified     2019-12-01 11:28:29-05:00
# comm_count                                   8
# word_count                                 146
# Name: 6184, dtype: object
#
#
# 0.8535058782394069
# Unnamed: 0                              34070
# article_num                              4524
# comment_id                              37235
# commenter_name                         vic123
# comment_published    2018-01-16T00:23:50.000Z
# comment_text               Tag Heuer Carrera?
# comment_likes                               1
# comment_flag                                0
# parent_id                                   0
# Name: 7013, dtype: object
# article_id                                             6268
# article_cat                                        Hands-On
# article_title        The TAG Heuer Carrera Calibre Heuer 02
# article_author                                 James Stacey
# article_published                 2019-12-18 09:03:00-05:00
# article_modified                  2019-12-18 09:25:40-05:00
# comm_count                                               11
# word_count                                             1054
# Name: 6235, dtype: object
#
#
# 49
